# %% [markdown]
# ### Doodle Classifier Project

# %% [markdown]
# ### Dependencies

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
gpus = tf.config.experimental.list_physical_devices("GPU")
for gpu in gpus:
	tf.config.experimental.set_memory_growth(gpu,True)

for gpu in gpus:
	print(gpu)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %% [markdown]
# ### Loading the data

# %%
train_df = tf.keras.preprocessing.image_dataset_from_directory("Data/train",color_mode="grayscale",image_size=(256,256))

class_names = train_df.class_names
print(class_names)
# Out:
# Found 32640 files belonging to 51 classes.
# ['airplane', 'anvil', 'apple', 'axe', 'banana', 'bandage', 'baseball', 'basketball', 'bed', 'bee', 'bicycle', 'blackberry', 'book', 'bowtie', 'bus', 'butterfly', 'cake', 'calculator', 'calendar', 'campfire', 'car', 'carrot', 'cat', 'cell phone', 'circle', 'cloud', 'coffee cup', 'computer', 'cookie', 'diamond', 'dog', 'donut', 'envelope', 'eye', 'face', 'fish', 'flower', 'guitar', 'hammer', 'hat', 'headphones', 'house', 'ice cream', 'lollipop', 'pants', 'pizza', 'skull', 'smiley face', 't-shirt', 'underwear', 'wristwatch']

# %%
for x in range(3):
    batch = train_df.as_numpy_iterator().next()
    fig,ax = plt.subplots(ncols = 10,figsize = (20,20))
    for idx,img in enumerate(batch[0][:10]):
    	ax[idx].imshow(img.astype(int),cmap = "gray")
    	ax[idx].title.set_text(class_names[batch[1][idx]])

# %% [markdown]
# ### Preprocessing the Data

# %%
data_aug = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    zoom_range=0.2,
    fill_mode="nearest",
validation_split=0.2)

preprocessed_train = data_aug.flow_from_directory("Data/train",color_mode="rgb",target_size=(256,256),subset="training")
val_df = data_aug.flow_from_directory("Data/train",color_mode="rgb",target_size=(256,256),subset="validation")
# Out:
# Found 26112 images belonging to 51 classes.
# Found 6528 images belonging to 51 classes.

# %% [markdown]
# ### Building the Neural Network

# %%
vgg = tf.keras.applications.VGG16(include_top = False,input_shape=(256,256,3))

for layers in vgg.layers:
    layers.trainable = False

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Input(shape=(256,256,1)))
model.add(tf.keras.layers.Conv2D(32,kernel_size=3))
model.add(tf.keras.layers.LeakyReLU(0.2))
model.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

model.add(tf.keras.layers.Conv2D(64,kernel_size=3))
model.add(tf.keras.layers.LeakyReLU(0.2))
model.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# model.add(tf.keras.layers.Conv2D(256,kernel_size=3))
# model.add(tf.keras.layers.LeakyReLU(0.2))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(64,activation = "relu"))
model.add(tf.keras.layers.Dense(51,activation = "softmax"))



model = tf.keras.models.Sequential()

model.add(vgg)
model.add(tf.keras.layers.GlobalAveragePooling2D())
model.add(tf.keras.layers.Dense(64,activation = "relu"))
model.add(tf.keras.layers.Dense(51,activation = "softmax"))

# %%
LOSS = "mse"
METRICS = ["accuracy"]
OPTIMIZERS = "adam"

model.compile(loss = LOSS,optimizer = OPTIMIZERS,metrics = METRICS)
model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  global_average_pooling2d_6   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_36 (Dense)            (None, 64)                32832
#
#  dense_37 (Dense)            (None, 51)                3315
#
# =================================================================
# Total params: 14,750,835
# Trainable params: 36,147
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
callbacks = tf.keras.callbacks.ModelCheckpoint(filepath="log")
model.fit(preprocessed_train,epochs = 15,batch_size = 32,callbacks=callbacks,validation_data=val_df,validation_batch_size=32)
# Out:
# Epoch 1/15
# 816/816 [==============================] - ETA: 0s - loss: 2.8900 - accuracy: 0.2977
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 174s 212ms/step - loss: 2.8900 - accuracy: 0.2977 - val_loss: 2.0537 - val_accuracy: 0.4807
# Epoch 2/15
# 816/816 [==============================] - ETA: 0s - loss: 1.7366 - accuracy: 0.5481
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 169s 207ms/step - loss: 1.7366 - accuracy: 0.5481 - val_loss: 1.4998 - val_accuracy: 0.6054
# Epoch 3/15
# 816/816 [==============================] - ETA: 0s - loss: 1.3557 - accuracy: 0.6387
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 170s 208ms/step - loss: 1.3557 - accuracy: 0.6387 - val_loss: 1.2488 - val_accuracy: 0.6682
# Epoch 4/15
# 816/816 [==============================] - ETA: 0s - loss: 1.1551 - accuracy: 0.6888
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 169s 207ms/step - loss: 1.1551 - accuracy: 0.6888 - val_loss: 1.0809 - val_accuracy: 0.7168
# Epoch 5/15
# 816/816 [==============================] - ETA: 0s - loss: 1.0292 - accuracy: 0.7207
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 171s 209ms/step - loss: 1.0292 - accuracy: 0.7207 - val_loss: 0.9982 - val_accuracy: 0.7255
# Epoch 6/15
# 816/816 [==============================] - ETA: 0s - loss: 0.9420 - accuracy: 0.7394
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 170s 209ms/step - loss: 0.9420 - accuracy: 0.7394 - val_loss: 0.9220 - val_accuracy: 0.7485
# Epoch 7/15
# 816/816 [==============================] - ETA: 0s - loss: 0.8796 - accuracy: 0.7574
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 172s 210ms/step - loss: 0.8796 - accuracy: 0.7574 - val_loss: 0.8703 - val_accuracy: 0.7560
# Epoch 8/15
# 816/816 [==============================] - ETA: 0s - loss: 0.8253 - accuracy: 0.7706
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 172s 210ms/step - loss: 0.8253 - accuracy: 0.7706 - val_loss: 0.8183 - val_accuracy: 0.7687
# Epoch 9/15
# 816/816 [==============================] - ETA: 0s - loss: 0.7860 - accuracy: 0.7808
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 170s 209ms/step - loss: 0.7860 - accuracy: 0.7808 - val_loss: 0.7904 - val_accuracy: 0.7779
# Epoch 10/15
# 816/816 [==============================] - ETA: 0s - loss: 0.7483 - accuracy: 0.7898
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 170s 209ms/step - loss: 0.7483 - accuracy: 0.7898 - val_loss: 0.7638 - val_accuracy: 0.7817
# Epoch 11/15
# 816/816 [==============================] - ETA: 0s - loss: 0.7275 - accuracy: 0.7953
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 172s 211ms/step - loss: 0.7275 - accuracy: 0.7953 - val_loss: 0.7249 - val_accuracy: 0.7952
# Epoch 12/15
# 816/816 [==============================] - ETA: 0s - loss: 0.6981 - accuracy: 0.8038
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 171s 210ms/step - loss: 0.6981 - accuracy: 0.8038 - val_loss: 0.7095 - val_accuracy: 0.7937
# Epoch 13/15
# 816/816 [==============================] - ETA: 0s - loss: 0.6720 - accuracy: 0.8105
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 170s 208ms/step - loss: 0.6720 - accuracy: 0.8105 - val_loss: 0.7079 - val_accuracy: 0.7987
# Epoch 14/15
# 816/816 [==============================] - ETA: 0s - loss: 0.6580 - accuracy: 0.8139
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 170s 208ms/step - loss: 0.6580 - accuracy: 0.8139 - val_loss: 0.6988 - val_accuracy: 0.7947
# Epoch 15/15
# 816/816 [==============================] - ETA: 0s - loss: 0.6402 - accuracy: 0.8151
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: log\assets
# INFO:tensorflow:Assets written to: log\assets
# 816/816 [==============================] - 173s 211ms/step - loss: 0.6402 - accuracy: 0.8151 - val_loss: 0.6525 - val_accuracy: 0.8136
